# %% [markdown]
# # Decoding JSON COLUMN

# %%
import numpy as np
import pandas as pd
import json #module needed to decode json format columns
from IPython.display import display
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DS1_C7_Part1_Data_Analysis_Using_Python_Dataset.csv')#importing the csv file

genres = data['genres'] #pulling the 'genres' column

display(genres)
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                   []
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
column_list = genres.tolist() #converting the genres column to a list
type(column_list)

new_list = [] #creating a new empty list

for y in genres:#for loop that iterates through each value in the list
        
    marcos = pd.read_json(y) #converts each value to json readable format
    new_list.append(marcos.iloc[:,-1:].values.tolist())
data['col'] = new_list #adding this list as a new column in the existing dataframe

display(data)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Task1
# Displaying the first 50 movies on the dataset

# %%
data[['title','col']][:50]
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # Task3
# Display the movie categories that have a budget greater than 220k

# %%
df_bud = data[(data.budget > 22000)]
df_bud[['col','title']]
# Out:
#                                                     col  \
# 0     [[Action], [Adventure], [Fantasy], [Science Fi...
# 1                    [[Adventure], [Fantasy], [Action]]
# 2                      [[Action], [Adventure], [Crime]]
# 3              [[Action], [Crime], [Drama], [Thriller]]
# 4            [[Action], [Adventure], [Science Fiction]]
# ...                                                 ...
# 4770                                [[Drama], [Comedy]]
# 4772                      [[Drama], [Action], [Comedy]]
# 4773                                         [[Comedy]]
# 4774                               [[Drama], [Romance]]
# 4798                    [[Action], [Crime], [Thriller]]
#
#                                          title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...

# %% [markdown]
# # Task 4
# Display the movie categories that have a revenue greater than $961 million

# %%
df_rev = data[(data.revenue > 961000000)]
display(df_rev[['col','title']].head())
# Out:
#                                                   col  \
# 0   [[Action], [Adventure], [Fantasy], [Science Fi...
# 3            [[Action], [Crime], [Drama], [Thriller]]
# 7          [[Action], [Adventure], [Science Fiction]]
# 12                 [[Adventure], [Fantasy], [Action]]
# 16         [[Science Fiction], [Action], [Adventure]]
#
#                                          title
# 0                                       Avatar
# 3                        The Dark Knight Rises
# 7                      Avengers: Age of Ultron
# 12  Pirates of the Caribbean: Dead Man's Chest
# 16                                The Avengers

# %% [markdown]
# #### Movies titles and genres with the highest popularity score

# %%
popularity = data[['title','col','popularity']].sort_values(by = 'popularity',ascending = False)[:10]
popularity
# Out:
#                                                  title  \
# 546                                            Minions
# 95                                        Interstellar
# 788                                           Deadpool
# 94                             Guardians of the Galaxy
# 127                                 Mad Max: Fury Road
# 28                                      Jurassic World
# 199  Pirates of the Caribbean: The Curse of the Bla...
# 82                      Dawn of the Planet of the Apes
# 200              The Hunger Games: Mockingjay - Part 1
# 88                                          Big Hero 6
#
#                                                    col  popularity
# 546     [[Family], [Animation], [Adventure], [Comedy]]  875.581305
# 95           [[Adventure], [Drama], [Science Fiction]]  724.247784
# 788                  [[Action], [Adventure], [Comedy]]  514.569956
# 94          [[Action], [Science Fiction], [Adventure]]  481.098624
# ...

# %% [markdown]
# #### Movies titles and genres with the highest revenue

# %%
revenue = data[['title','col','revenue']].sort_values(by = 'revenue',ascending = False)[:10]
revenue
# Out:
#                           title  \
# 0                        Avatar
# 25                      Titanic
# 16                 The Avengers
# 28               Jurassic World
# 44                    Furious 7
# 7       Avengers: Age of Ultron
# 124                      Frozen
# 31                   Iron Man 3
# 546                     Minions
# 26   Captain America: Civil War
#
#                                                    col     revenue
# 0    [[Action], [Adventure], [Fantasy], [Science Fi...  2787965087
# 25                    [[Drama], [Romance], [Thriller]]  1845034188
# 16          [[Science Fiction], [Action], [Adventure]]  1519557910
# 28   [[Action], [Adventure], [Science Fiction], [Th...  1513528810
# 44                                          [[Action]]  1506249360
# 7           [[Action], [Adventure], [Science Fiction]]  1405403694
# 124               [[Animation], [Adventure], [Family]]  1274219009
# 31          [[Action], [Adventure], [Science Fiction]]  1215439994
# ...

# %% [markdown]
# #### Movies titles and genres with the highest voting average

# %%
vote_average = data[['title','col','vote_average']].sort_values(by = 'vote_average',ascending = False)[:10]
vote_average
# Out:
#                          title                                        col  \
# 3519          Stiff Upper Lips                                 [[Comedy]]
# 4247     Me You and Five Bucks             [[Romance], [Comedy], [Drama]]
# 4045     Dancer, Texas Pop. 81              [[Comedy], [Drama], [Family]]
# 4662            Little Big Top                                 [[Comedy]]
# 3992                 Sardaarji                                         []
# 2386            One Man's Hero  [[Western], [Action], [Drama], [History]]
# 2970        There Goes My Baby                        [[Drama], [Comedy]]
# 1881  The Shawshank Redemption                         [[Drama], [Crime]]
# 2796     The Prisoner of Zenda          [[Adventure], [Drama], [Romance]]
# 3337             The Godfather                         [[Drama], [Crime]]
#
#       vote_average
# 3519          10.0
# 4247          10.0
# 4045          10.0
# 4662          10.0
# 3992           9.5
# 2386           9.3
# ...

# %% [markdown]
# #### Movies titles and genres with the highest voting average

# %%
budget = data[['title','col','budget']].sort_values(by = 'budget',ascending = False)[:10]
budget
# Out:
#                                           title  \
# 17  Pirates of the Caribbean: On Stranger Tides
# 1      Pirates of the Caribbean: At World's End
# 7                       Avengers: Age of Ultron
# 10                             Superman Returns
# 4                                   John Carter
# 6                                       Tangled
# 5                                  Spider-Man 3
# 13                              The Lone Ranger
# 46                   X-Men: Days of Future Past
# 22          The Hobbit: The Desolation of Smaug
#
#                                                   col     budget
# 17                 [[Adventure], [Action], [Fantasy]]  380000000
# 1                  [[Adventure], [Fantasy], [Action]]  300000000
# 7          [[Action], [Adventure], [Science Fiction]]  280000000
# 10  [[Adventure], [Fantasy], [Action], [Science Fi...  270000000
# 4          [[Action], [Adventure], [Science Fiction]]  260000000
# ...

# %%
colors = ['blue','red']
plt.bar(popularity['title'], popularity['popularity'], color=colors)
plt.title('Popularity Score of Movies', fontsize=12)
plt.ylabel('Popularity Score', fontsize=14)
plt.xlabel('Movie Title', fontsize=14)
plt.xticks(rotation = 90)

#plt.grid(True)
plt.show()

# %%
#Adding the Data
x1 = data['revenue'].to_numpy()
y1 = data['popularity'].to_numpy()
#Add an Axes to the current figure and make it the current Axes.
ax1 = plt.axes()

#creating the scatter plot
ax1.scatter(x1,y1, c = 'c', edgecolors="k")

#adding a title and axis labels
ax1.set_title('Popularity vs Revenue')
ax1.set_ylabel('Popularity')
ax1.set_xlabel('Revenue')


#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x1, y1, 1)

#add linear regression line to scatterplot 
plt.plot(x1, m*x1+b, c='r')


plt.show() #displays the graph
